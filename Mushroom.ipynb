# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mushroom_df=pd.read_csv("mushrooms.csv")

# %%
mushroom_df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
mushroom_df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
mushroom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
mushroom_df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
mushroom_df.isna().sum()
#mushroom_df[mushroom_df.isnull().any(axis=1)]
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# # conerting into numerical values

# %%
#cleanup_nums={"class":{'e':1,'p':2}} 
#mushroom_df=mushroom_df.replace(cleanup_nums) or

# %%
mushroom_df[['class']] = mushroom_df[['class']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['cap-shape']] = mushroom_df[['cap-shape']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['cap-surface']] = mushroom_df[['cap-surface']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['cap-color']] = mushroom_df[['cap-color']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['bruises']] = mushroom_df[['bruises']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df['odor']=mushroom_df[['odor']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['gill-attachment']] = mushroom_df[['gill-attachment']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['gill-spacing']] = mushroom_df[['gill-spacing']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['gill-size']] = mushroom_df[['gill-size']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['gill-color']] = mushroom_df[['gill-color']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['stalk-shape']] = mushroom_df[['stalk-shape']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['stalk-root']] = mushroom_df[['stalk-root']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['stalk-surface-above-ring']] = mushroom_df[['stalk-surface-above-ring']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['stalk-surface-below-ring']] = mushroom_df[['stalk-surface-below-ring']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['stalk-color-above-ring']] = mushroom_df[['stalk-color-above-ring']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df[['stalk-color-below-ring']] = mushroom_df[['stalk-color-below-ring']].apply(lambda col:pd.Categorical(col).codes)
mushroom_df[['veil-type']] = mushroom_df[['veil-type']].apply(lambda col:pd.Categorical(col).codes)

mushroom_df[['veil-color']] = mushroom_df[['veil-color']].apply(lambda col:pd.Categorical(col).codes)
mushroom_df[['ring-number']] = mushroom_df[['ring-number']].apply(lambda col:pd.Categorical(col).codes)
mushroom_df[['ring-type']] = mushroom_df[['ring-type']].apply(lambda col:pd.Categorical(col).codes)
mushroom_df[['spore-print-color']] = mushroom_df[['spore-print-color']].apply(lambda col:pd.Categorical(col).codes)
mushroom_df[['population']] = mushroom_df[['population']].apply(lambda col:pd.Categorical(col).codes)
mushroom_df[['habitat']] = mushroom_df[['habitat']].apply(lambda col:pd.Categorical(col).codes)

# %%
mushroom_df.dtypes
# Out:
# class                       int8
# cap-shape                   int8
# cap-surface                 int8
# cap-color                   int8
# bruises                     int8
# odor                        int8
# gill-attachment             int8
# gill-spacing                int8
# gill-size                   int8
# gill-color                  int8
# stalk-shape                 int8
# stalk-root                  int8
# stalk-surface-above-ring    int8
# stalk-surface-below-ring    int8
# stalk-color-above-ring      int8
# stalk-color-below-ring      int8
# veil-type                   int8
# veil-color                  int8
# ring-number                 int8
# ring-type                   int8
# spore-print-color           int8
# population                  int8
# habitat                     int8
# dtype: object

# %%
sns.pairplot(mushroom_df)

# %%
sns.heatmap(mushroom_df.corr())

# %%
sns.distplot(mushroom_df['class'])

# %%
x=mushroom_df[['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']]

# %%
y=mushroom_df['class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=111)

# %%
x_train.shape
# Out:
# (6499, 22)

# %%
x_test.shape
# Out:
# (1625, 22)

# %%
y_train.shape
# Out:
# (6499,)

# %%
y_test.shape
# Out:
# (1625,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
y_predict=knn.predict(x_test)

# %%
print(y_predict)
# Out:
# [0 1 0 ... 0 1 0]

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
cr=classification_report(y_test,y_predict)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       831
#            1       1.00      1.00      1.00       794
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %%
cm=confusion_matrix(y_test,y_predict)
print(cm)
# Out:
# [[831   0]
#  [  0 794]]

# %%
acuur_score=accuracy_score(y_true=y_test,y_pred=y_predict)
print("overall accuracy of knn model using test_set is: %2f"%(acuur_score*100))
# Out:
# overall accuracy of knn model using test_set is: 100.000000
